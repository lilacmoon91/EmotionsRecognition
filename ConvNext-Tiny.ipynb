# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torchvision.models as models
import numpy as np
from sklearn.metrics import confusion_matrix, accuracy_score, precision_recall_fscore_support
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.auto import tqdm
import warnings
import os
import random
from PIL import Image
from pathlib import Path
import copy
import pickle

warnings.filterwarnings('ignore')


class FocalLoss(nn.Module):
    def __init__(self, gamma=1.5, alpha=None, reduction='mean'):
        super().__init__()
        self.gamma = gamma
        self.alpha = alpha
        self.reduction = reduction

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = (1 - pt) ** self.gamma * ce_loss

        if self.alpha is not None:
            alpha_t = self.alpha[targets]
            focal_loss = alpha_t * focal_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        return focal_loss.sum()


class ConvNeXtEmotion(nn.Module):
    def __init__(self, num_classes=7, pretrained=True):
        super().__init__()
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        weights = models.ConvNeXt_Tiny_Weights.IMAGENET1K_V1 if pretrained else None
        self.backbone = models.convnext_tiny(weights=weights)

        in_features = 768

        self.backbone.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.LayerNorm(in_features),
            nn.Dropout(p=0.35),
            nn.Linear(in_features, 512),
            nn.GELU(),
            nn.Dropout(p=0.2),
            nn.Linear(512, num_classes)
        )

        self.to(self.device)

    def forward(self, x):
        return self.backbone(x)


class RAFDBDataset(Dataset):
    def __init__(self, root_dir, split='train'):
        self.root_dir = Path(root_dir) / split
        self.is_train = 'train' in str(self.root_dir).lower()
        self.images = []
        self.labels = []
        self._load_data()

        if self.is_train:
            self.transform = transforms.Compose([
                transforms.RandomResizedCrop(224, scale=(0.82, 1.0), ratio=(0.9, 1.1)),
                transforms.RandomHorizontalFlip(p=0.5),
                transforms.RandomRotation(degrees=12),
                transforms.RandomApply([
                    transforms.ColorJitter(brightness=0.12, contrast=0.12, saturation=0.08)
                ], p=0.6),
                transforms.ToTensor(),
                transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225]),
                transforms.RandomErasing(p=0.25,
                                         scale=(0.02, 0.15),
                                         ratio=(0.3, 3.3),
                                         value=0)
            ])
        else:
            self.transform = transforms.Compose([
                transforms.Resize(256),
                transforms.CenterCrop(224),
                transforms.ToTensor(),
                transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225]),
            ])

    def _load_data(self):
        for class_folder in sorted(self.root_dir.iterdir()):
            if not class_folder.is_dir():
                continue
            try:
                class_idx = int(class_folder.name)
                if class_idx not in range(1, 8):
                    continue
                label = class_idx - 1
                for img_path in class_folder.glob('*.[jp][pn]g'):
                    self.images.append(str(img_path))
                    self.labels.append(label)
            except Exception:
                continue

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = self.labels[idx]

        image = Image.open(img_path).convert('RGB')

        image = self.transform(image)

        return image, torch.tensor(label, dtype=torch.long)

    def __len__(self):
        return len(self.images)


class FixedSplitDataset(Dataset):
    def __init__(self, base_dataset, indices):
        self.base_dataset = base_dataset
        self.indices = indices

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, idx):
        return self.base_dataset[self.indices[idx]]


def load_fixed_split(root_dir, splits_path="dataset_splits.pkl"):
    with open(splits_path, 'rb') as f:
        splits = pickle.load(f)

    full_train_base = RAFDBDataset(root_dir, 'train')

    test_ds = RAFDBDataset(root_dir, 'test')

    train_ds = FixedSplitDataset(full_train_base, splits['train_indices'])
    val_ds   = FixedSplitDataset(full_train_base, splits['val_indices'])

    emotion_labels = {
        0: 'Surprise', 1: 'Fear', 2: 'Disgust',
        3: 'Happiness', 4: 'Sadness', 5: 'Anger', 6: 'Neutral'
    }

    return train_ds, val_ds, test_ds, emotion_labels


def create_dataloaders(batch_size=32, root_dir=None, splits_path=None):
    train_ds, val_ds, test_ds, emotion_labels = load_fixed_split(root_dir, splits_path)

    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True)
    val_loader = DataLoader(val_ds, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)
    test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)

    return train_loader, val_loader, test_loader, emotion_labels


def train_model(model, train_loader, val_loader, criterion, optimizer,
                scheduler, num_epochs=50, device='cpu',
                patience=12, min_delta=0.001, save_dir="checkpoints"):

    os.makedirs(save_dir, exist_ok=True)

    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []

    best_val_acc = -float('inf')
    best_model_state = None
    best_epoch = 0
    epochs_no_improve = 0

    print(f"Early stopping: patience={patience}, min_delta={min_delta}")
    print(f"Модели будут сохраняться в папку: {save_dir}/\n")

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        train_pbar = tqdm(train_loader, desc=f'Epoch {epoch+1}/{num_epochs} [Train]')

        for inputs, labels in train_pbar:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

            train_pbar.set_postfix({'Loss': f'{loss.item():.4f}', 'Acc': f'{100.*correct/total:.2f}%'})

        train_loss = running_loss / len(train_loader)
        train_acc = 100. * correct / total
        train_losses.append(train_loss)
        train_accs.append(train_acc)

        
        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0

        with torch.no_grad():
            val_pbar = tqdm(val_loader, desc=f'Epoch {epoch+1}/{num_epochs} [Val]')

            for inputs, labels in val_pbar:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item()
                _, predicted = outputs.max(1)
                total += labels.size(0)
                correct += predicted.eq(labels).sum().item()

                val_pbar.set_postfix({'Loss': f'{loss.item():.4f}', 'Acc': f'{100.*correct/total:.2f}%'})

        val_loss = val_loss / len(val_loader)
        val_acc = 100. * correct / total
        val_losses.append(val_loss)
        val_accs.append(val_acc)

        if scheduler is not None:
            scheduler.step(val_loss)

        
        checkpoint = {
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict() if scheduler else None,
            'val_acc': val_acc,
            'val_loss': val_loss,
            'train_acc': train_acc,
            'train_loss': train_loss,
        }

        torch.save(checkpoint, f"{save_dir}/epoch_{epoch+1:03d}.pth")

        
        if val_acc > best_val_acc + min_delta:
            best_val_acc = val_acc
            best_epoch = epoch + 1
            best_model_state = copy.deepcopy(model.state_dict())
            epochs_no_improve = 0

            
            best_checkpoint = {
                'epoch': best_epoch,
                'model_state_dict': best_model_state,
                'val_acc': best_val_acc,
                'val_loss': val_loss,
            }
            torch.save(best_checkpoint, f"{save_dir}/best_model.pth")

            print(f"Новая лучшая Val Acc: {val_acc:.2f}% (эпоха {best_epoch}) — сохранена best_model.pth")
        else:
            epochs_no_improve += 1
            print(f"Нет улучшения Val Acc ({epochs_no_improve}/{patience})")

            if epochs_no_improve >= patience:
                print(f"\nEarly stopping на эпохе {epoch+1}")
                print(f"Лучшая Val Acc: {best_val_acc:.2f}% (эпоха {best_epoch})")
                break

        print(f'Epoch {epoch+1}/{num_epochs}: '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}% | '
              f'Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%')


    if best_model_state is not None:
        model.load_state_dict(best_model_state)
        print(f"\nЗагружена лучшая модель (эпоха {best_epoch}) с Val Acc: {best_val_acc:.2f}%")

    return {
        'train_losses': train_losses,
        'val_losses': val_losses,
        'train_accs': train_accs,
        'val_accs': val_accs,
        'best_val_acc': best_val_acc,
        'best_epoch': best_epoch,
        'stopped_epoch': epoch + 1 if epochs_no_improve >= patience else num_epochs
    }


def test_model(model, test_loader, criterion, device, emotion_labels):
    model.eval()
    all_preds = []
    all_labels = []
    test_loss = 0.0

    with torch.no_grad():
        for inputs, labels in tqdm(test_loader, desc='Тестирование'):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    test_loss /= len(test_loader)
    test_acc = accuracy_score(all_labels, all_preds) * 100

    precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average=None, zero_division=0)
    _, _, f1_macro, _ = precision_recall_fscore_support(all_labels, all_preds, average='macro', zero_division=0)

    print(f"\nTest Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_acc:.2f}%")
    print(f"Macro F1-Score: {f1_macro:.4f}")

    print("\nPer-class metrics:")
    for i, lbl in emotion_labels.items():
        print(f" {lbl}: F1={f1[i]:.3f}, Prec={precision[i]:.3f}, Rec={recall[i]:.3f}")

    return all_preds, all_labels, test_loss, test_acc


def plot_confusion_matrix(y_true, y_pred, emotion_labels):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=list(emotion_labels.values()),
                yticklabels=list(emotion_labels.values()))
    plt.title('Confusion Matrix - ConvNeXt-Tiny')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()
    plt.show()


def plot_training_history(history):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    axes[0].plot(history['train_losses'], label='Train Loss')
    axes[0].plot(history['val_losses'], label='Val Loss')
    axes[0].set_title('Loss')
    axes[0].legend()
    axes[0].grid(True)

    axes[1].plot(history['train_accs'], label='Train Acc')
    axes[1].plot(history['val_accs'], label='Val Acc')
    axes[1].set_title('Accuracy')
    axes[1].legend()
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()


def main():
    print("РАСПОЗНАВАНИЕ ЭМОЦИЙ НА RAF-DB")
    print("ConvNeXt-Tiny (ImageNet-1K)")

    RAFDB_ROOT = r"DATASET"
    SPLITS_PATH = "dataset_splits.pkl"

    BATCH_SIZE = 32
    LEARNING_RATE = 5e-5
    NUM_EPOCHS = 50
    RANDOM_SEED = 42

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Устройство: {device}")

    torch.manual_seed(RANDOM_SEED)
    np.random.seed(RANDOM_SEED)
    random.seed(RANDOM_SEED)

    print("\n1. Загрузка данных")
    train_loader, val_loader, test_loader, emotion_labels = create_dataloaders(
        batch_size=BATCH_SIZE,
        root_dir=RAFDB_ROOT,
        splits_path=SPLITS_PATH
    )

    print(f"  Train: {len(train_loader.dataset):6d}")
    print(f"  Val:   {len(val_loader.dataset):6d}")
    print(f"  Test:  {len(test_loader.dataset):6d}")

    print("\n2. Создание модели (ConvNeXt-Tiny ImageNet)")
    model = ConvNeXtEmotion(num_classes=7, pretrained=True)
    print(f"  Всего параметров: {sum(p.numel() for p in model.parameters()):,}")

    criterion = FocalLoss(gamma=1.5, alpha=None)

    optimizer = optim.AdamW(
        model.parameters(),
        lr=LEARNING_RATE,
        weight_decay=3e-5
    )

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='min',
        factor=0.5,
        patience=3,
        min_lr=1e-7
    )

    print("\n3. Начало обучения ConvNeXt-Tiny")
    CHECKPOINT_DIR = "checkpoints_convnext_tiny"
    os.makedirs(CHECKPOINT_DIR, exist_ok=True)

    history = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        criterion=criterion,
        optimizer=optimizer,
        scheduler=scheduler,
        num_epochs=NUM_EPOCHS,
        device=device,
        patience=12,
        min_delta=0.001,
        save_dir=CHECKPOINT_DIR
    )

    print("\n4. Визуализация кривых обучения")
    plot_training_history(history)

    print("\n5. Тестирование")
    all_preds, all_labels, test_loss, test_acc = test_model(
        model=model,
        test_loader=test_loader,
        criterion=criterion,
        device=device,
        emotion_labels=emotion_labels
    )

    plot_confusion_matrix(all_labels, all_preds, emotion_labels)

    print("\n6. Сохранение финальной модели")
    os.makedirs("results", exist_ok=True)

    final_checkpoint = {
        'model_state_dict': model.state_dict(),
        'history': history,
        'test_acc': test_acc,
        'best_val_acc': history['best_val_acc'],
        'best_epoch': history.get('best_epoch', None)
    }

    torch.save(final_checkpoint, "results/rafdb_convnext_tiny_focal_aug_final.pth")
    print("Финальная модель сохранена в: results/rafdb_convnext_tiny_focal_aug_final.pth")

    print("\n")
    print(f"ИТОГОВАЯ ТОЧНОСТЬ НА ТЕСТЕ: {test_acc:.2f}%")


if __name__ == "__main__":
    main()
# Out:
# РАСПОЗНАВАНИЕ ЭМОЦИЙ НА RAF-DB
# ConvNeXt-Tiny (ImageNet-1K)
# Устройство: cuda
#
# 1. Загрузка данных
#   Train:  10430
#   Val:     1841
#   Test:    3068
#
# 2. Создание модели (ConvNeXt-Tiny ImageNet)
#   Всего параметров: 28,217,447
#
# 3. Начало обучения ConvNeXt-Tiny
# Early stopping: patience=12, min_delta=0.001
# Модели будут сохраняться в папку: checkpoints_convnext_tiny/
# Epoch 1/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 1/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Новая лучшая Val Acc: 73.55% (эпоха 1) — сохранена best_model.pth
# Epoch 1/50: Train Loss: 0.7770, Train Acc: 60.55% | Val Loss: 0.5007, Val Acc: 73.55%
# Epoch 2/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 2/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Новая лучшая Val Acc: 78.82% (эпоха 2) — сохранена best_model.pth
# Epoch 2/50: Train Loss: 0.4562, Train Acc: 75.06% | Val Loss: 0.3965, Val Acc: 78.82%
# Epoch 3/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 3/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Новая лучшая Val Acc: 80.17% (эпоха 3) — сохранена best_model.pth
# Epoch 3/50: Train Loss: 0.3497, Train Acc: 80.12% | Val Loss: 0.3513, Val Acc: 80.17%
# Epoch 4/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 4/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Новая лучшая Val Acc: 81.10% (эпоха 4) — сохранена best_model.pth
# Epoch 4/50: Train Loss: 0.2838, Train Acc: 83.61% | Val Loss: 0.3356, Val Acc: 81.10%
# Epoch 5/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 5/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Новая лучшая Val Acc: 81.15% (эпоха 5) — сохранена best_model.pth
# Epoch 5/50: Train Loss: 0.2246, Train Acc: 86.32% | Val Loss: 0.3344, Val Acc: 81.15%
# Epoch 6/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 6/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Новая лучшая Val Acc: 82.62% (эпоха 6) — сохранена best_model.pth
# Epoch 6/50: Train Loss: 0.1776, Train Acc: 88.57% | Val Loss: 0.3175, Val Acc: 82.62%
# Epoch 7/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 7/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Новая лучшая Val Acc: 82.84% (эпоха 7) — сохранена best_model.pth
# Epoch 7/50: Train Loss: 0.1556, Train Acc: 89.87% | Val Loss: 0.3196, Val Acc: 82.84%
# Epoch 8/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 8/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Новая лучшая Val Acc: 83.49% (эпоха 8) — сохранена best_model.pth
# Epoch 8/50: Train Loss: 0.1194, Train Acc: 91.74% | Val Loss: 0.3336, Val Acc: 83.49%
# Epoch 9/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 9/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Нет улучшения Val Acc (1/12)
# Epoch 9/50: Train Loss: 0.1021, Train Acc: 93.03% | Val Loss: 0.3634, Val Acc: 82.07%
# Epoch 10/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 10/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Новая лучшая Val Acc: 83.98% (эпоха 10) — сохранена best_model.pth
# Epoch 10/50: Train Loss: 0.0864, Train Acc: 93.81% | Val Loss: 0.3343, Val Acc: 83.98%
# Epoch 11/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 11/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Новая лучшая Val Acc: 84.52% (эпоха 11) — сохранена best_model.pth
# Epoch 11/50: Train Loss: 0.0570, Train Acc: 95.85% | Val Loss: 0.3227, Val Acc: 84.52%
# Epoch 12/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 12/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Нет улучшения Val Acc (1/12)
# Epoch 12/50: Train Loss: 0.0452, Train Acc: 96.81% | Val Loss: 0.3554, Val Acc: 83.98%
# Epoch 13/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 13/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Нет улучшения Val Acc (2/12)
# Epoch 13/50: Train Loss: 0.0382, Train Acc: 97.43% | Val Loss: 0.3667, Val Acc: 83.32%
# Epoch 14/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 14/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Новая лучшая Val Acc: 84.85% (эпоха 14) — сохранена best_model.pth
# Epoch 14/50: Train Loss: 0.0400, Train Acc: 97.09% | Val Loss: 0.3296, Val Acc: 84.85%
# Epoch 15/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 15/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Новая лучшая Val Acc: 85.01% (эпоха 15) — сохранена best_model.pth
# Epoch 15/50: Train Loss: 0.0263, Train Acc: 98.09% | Val Loss: 0.3383, Val Acc: 85.01%
# Epoch 16/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 16/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Нет улучшения Val Acc (1/12)
# Epoch 16/50: Train Loss: 0.0276, Train Acc: 97.97% | Val Loss: 0.3734, Val Acc: 84.41%
# Epoch 17/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 17/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Новая лучшая Val Acc: 85.23% (эпоха 17) — сохранена best_model.pth
# Epoch 17/50: Train Loss: 0.0270, Train Acc: 98.23% | Val Loss: 0.3498, Val Acc: 85.23%
# Epoch 18/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 18/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Новая лучшая Val Acc: 85.77% (эпоха 18) — сохранена best_model.pth
# Epoch 18/50: Train Loss: 0.0226, Train Acc: 98.40% | Val Loss: 0.3594, Val Acc: 85.77%
# Epoch 19/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 19/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Нет улучшения Val Acc (1/12)
# Epoch 19/50: Train Loss: 0.0215, Train Acc: 98.49% | Val Loss: 0.3699, Val Acc: 84.90%
# Epoch 20/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 20/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Новая лучшая Val Acc: 86.26% (эпоха 20) — сохранена best_model.pth
# Epoch 20/50: Train Loss: 0.0193, Train Acc: 98.61% | Val Loss: 0.3643, Val Acc: 86.26%
# Epoch 21/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 21/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Нет улучшения Val Acc (1/12)
# Epoch 21/50: Train Loss: 0.0191, Train Acc: 98.71% | Val Loss: 0.3765, Val Acc: 85.06%
# Epoch 22/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 22/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Нет улучшения Val Acc (2/12)
# Epoch 22/50: Train Loss: 0.0187, Train Acc: 98.68% | Val Loss: 0.3797, Val Acc: 85.23%
# Epoch 23/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 23/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Нет улучшения Val Acc (3/12)
# Epoch 23/50: Train Loss: 0.0169, Train Acc: 98.88% | Val Loss: 0.3738, Val Acc: 85.12%
# Epoch 24/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 24/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Нет улучшения Val Acc (4/12)
# Epoch 24/50: Train Loss: 0.0144, Train Acc: 99.14% | Val Loss: 0.3859, Val Acc: 84.57%
# Epoch 25/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 25/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Нет улучшения Val Acc (5/12)
# Epoch 25/50: Train Loss: 0.0152, Train Acc: 98.93% | Val Loss: 0.3818, Val Acc: 85.06%
# Epoch 26/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 26/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Нет улучшения Val Acc (6/12)
# Epoch 26/50: Train Loss: 0.0122, Train Acc: 99.14% | Val Loss: 0.3896, Val Acc: 85.06%
# Epoch 27/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 27/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Нет улучшения Val Acc (7/12)
# Epoch 27/50: Train Loss: 0.0143, Train Acc: 98.88% | Val Loss: 0.3651, Val Acc: 85.71%
# Epoch 28/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 28/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Нет улучшения Val Acc (8/12)
# Epoch 28/50: Train Loss: 0.0159, Train Acc: 99.00% | Val Loss: 0.3749, Val Acc: 84.63%
# Epoch 29/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 29/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Нет улучшения Val Acc (9/12)
# Epoch 29/50: Train Loss: 0.0149, Train Acc: 99.00% | Val Loss: 0.3726, Val Acc: 85.55%
# Epoch 30/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 30/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Нет улучшения Val Acc (10/12)
# Epoch 30/50: Train Loss: 0.0123, Train Acc: 99.13% | Val Loss: 0.3837, Val Acc: 85.44%
# Epoch 31/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 31/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Нет улучшения Val Acc (11/12)
# Epoch 31/50: Train Loss: 0.0140, Train Acc: 98.92% | Val Loss: 0.3788, Val Acc: 85.06%
# Epoch 32/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 32/50 [Val]:   0%|          | 0/58 [00:00<?, ?it/s]
# Нет улучшения Val Acc (12/12)
#
# Early stopping на эпохе 32
# Лучшая Val Acc: 86.26% (эпоха 20)
#
# Загружена лучшая модель (эпоха 20) с Val Acc: 86.26%
#
# 4. Визуализация кривых обучения
# 5. Тестирование
# Тестирование:   0%|          | 0/96 [00:00<?, ?it/s]
# Test Loss: 0.3293
# Test Accuracy: 86.64%
# Macro F1-Score: 0.7860
#
# Per-class metrics:
#  Surprise: F1=0.862, Prec=0.861, Rec=0.863
#  Fear: F1=0.610, Prec=0.642, Rec=0.581
#  Disgust: F1=0.608, Prec=0.690, Rec=0.544
#  Happiness: F1=0.939, Prec=0.914, Rec=0.965
#  Sadness: F1=0.846, Prec=0.865, Rec=0.828
#  Anger: F1=0.785, Prec=0.819, Rec=0.753
#  Neutral: F1=0.851, Prec=0.847, Rec=0.856
# 6. Сохранение финальной модели
# Финальная модель сохранена в: results/rafdb_convnext_tiny_focal_aug_final.pth
#
# ИТОГОВАЯ ТОЧНОСТЬ НА ТЕСТЕ: 86.64%
