# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torchvision.models as models
import numpy as np
from sklearn.metrics import confusion_matrix, accuracy_score, precision_recall_fscore_support
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.auto import tqdm
import warnings
import os
import random
from PIL import Image
from pathlib import Path
import copy
import pickle
warnings.filterwarnings('ignore')


class FocalLoss(nn.Module):
    def __init__(self, gamma=1.5, alpha=None, reduction='mean'):
        super().__init__()
        self.gamma = gamma
        self.alpha = alpha
        self.reduction = reduction

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = (1 - pt) ** self.gamma * ce_loss

        if self.alpha is not None:
            alpha_t = self.alpha[targets]
            focal_loss = alpha_t * focal_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        return focal_loss.sum()


class EfficientNetEmotion(nn.Module):
    def __init__(self, num_classes=7, pretrained=True):
        super().__init__()
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        weights = models.EfficientNet_B2_Weights.IMAGENET1K_V1 if pretrained else None
        self.backbone = models.efficientnet_b2(weights=weights)
        in_features = 1408

        self.backbone.classifier = nn.Sequential(
            nn.Dropout(p=0.3, inplace=True),
            nn.Linear(in_features, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.2),
            nn.Linear(256, num_classes)
        )

        self.to(self.device)

    def forward(self, x):
        x = x.to(self.device)
        return self.backbone(x)


class SimpleDataset(Dataset):
    def __init__(self, root_dir):
        self.root_dir = Path(root_dir)
        self.images = []
        self.labels = []
        self._load_data()

        self.transform = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225]),
        ])

    def _load_data(self):
        for class_folder in sorted(self.root_dir.iterdir()):
            if not class_folder.is_dir():
                continue
            try:
                class_idx = int(class_folder.name)
                if class_idx not in range(1, 8):
                    continue
                label = class_idx - 1
                for img_path in class_folder.glob('*.[jp][pn]g'):
                    self.images.append(str(img_path))
                    self.labels.append(label)
            except Exception as e:
                print(f"Ошибка при загрузке {class_folder}: {e}")
                continue

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = self.labels[idx]

        image = Image.open(img_path).convert('RGB')
        image = self.transform(image)

        return image, torch.tensor(label, dtype=torch.long)


class SimpleDatasetWithAugmentation(Dataset):
    def __init__(self, root_dir):
        self.root_dir = Path(root_dir)
        self.images = []
        self.labels = []
        self._load_data()

        self.transform = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomRotation(degrees=5),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225]),
        ])

    def _load_data(self):
        for class_folder in sorted(self.root_dir.iterdir()):
            if not class_folder.is_dir():
                continue
            try:
                class_idx = int(class_folder.name)
                if class_idx not in range(1, 8):
                    continue
                label = class_idx - 1
                for img_path in class_folder.glob('*.[jp][pn]g'):
                    self.images.append(str(img_path))
                    self.labels.append(label)
            except Exception as e:
                print(f"Ошибка: {e}")
                continue

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = self.labels[idx]

        image = Image.open(img_path).convert('RGB')
        image = self.transform(image)

        return image, torch.tensor(label, dtype=torch.long)


def create_dataloaders_from_folders(train_dir, val_dir, test_dir, batch_size=32):
    emotion_labels = {
        0: 'Surprise', 1: 'Fear', 2: 'Disgust',
        3: 'Happiness', 4: 'Sadness', 5: 'Anger', 6: 'Neutral'
    }

    train_dataset = SimpleDatasetWithAugmentation(train_dir)
    val_dataset = SimpleDataset(val_dir)
    test_dataset = SimpleDataset(test_dir)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0)

    return train_loader, val_loader, test_loader, emotion_labels


def train_model(model, train_loader, val_loader, criterion, optimizer,
                scheduler, num_epochs=40, device='cuda',
                patience=10, min_delta=0.001,
                checkpoint_dir="checkpoints"):

    os.makedirs(checkpoint_dir, exist_ok=True)

    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []

    best_val_acc = -float('inf')
    epochs_no_improve = 0
    best_epoch = 0

    print(f"Чекпоинты будут сохраняться после каждой эпохи в: ./{checkpoint_dir}/")
    print(f"Early stopping: patience={patience}, min_delta={min_delta}\n")

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        train_pbar = tqdm(train_loader, desc=f'Epoch {epoch+1}/{num_epochs} [Train]')

        for inputs, labels in train_pbar:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            train_pbar.set_postfix(Loss=f'{loss.item():.4f}', Acc=f'{100.*correct/total:.2f}%')

        train_loss = running_loss / len(train_loader)
        train_acc = 100. * correct / total
        train_losses.append(train_loss)
        train_accs.append(train_acc)

        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0

        with torch.no_grad():
            val_pbar = tqdm(val_loader, desc=f'Epoch {epoch+1}/{num_epochs} [Val]  ')

            for inputs, labels in val_pbar:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item()
                _, predicted = outputs.max(1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                val_pbar.set_postfix(Loss=f'{loss.item():.4f}', Acc=f'{100.*correct/total:.2f}%')

        val_loss = val_loss / len(val_loader)
        val_acc = 100. * correct / total
        val_losses.append(val_loss)
        val_accs.append(val_acc)

        if scheduler is not None:
            scheduler.step(val_loss)

        epoch_file = f"epoch_{epoch+1:03d}_val{val_acc:.2f}.pth"
        save_path = os.path.join(checkpoint_dir, epoch_file)

        torch.save({
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict() if scheduler else None,
            'train_loss': train_loss,
            'val_loss': val_loss,
            'train_acc': train_acc,
            'val_acc': val_acc,
        }, save_path)

        print(f"Сохранено: {epoch_file}   (val acc {val_acc:.2f}%)")

        improved = val_acc > best_val_acc + min_delta

        if improved:
            best_val_acc = val_acc
            best_epoch = epoch + 1
            epochs_no_improve = 0

            best_path = os.path.join(checkpoint_dir, "best_model.pth")
            torch.save({
                'epoch': best_epoch,
                'model_state_dict': model.state_dict(),
                'val_acc': best_val_acc,
            }, best_path)

            print(f"НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc {val_acc:.2f}% (эпоха {best_epoch})")
        else:
            epochs_no_improve += 1
            print(f"Нет улучшения ({epochs_no_improve}/{patience})")

            if epochs_no_improve >= patience:
                print(f"\nEarly stopping на эпохе {epoch+1}")
                print(f"Лучшая val acc: {best_val_acc:.2f}% (эпоха {best_epoch})")
                break

        print(f"Epoch {epoch+1:2d}/{num_epochs}: "
              f"train {train_loss:.4f} / {train_acc:5.2f}% | "
              f"val {val_loss:.4f} / {val_acc:5.2f}%\n")

    best_path = os.path.join(checkpoint_dir, "best_model.pth")
    if os.path.exists(best_path):
        ckpt = torch.load(best_path, map_location=device)
        model.load_state_dict(ckpt['model_state_dict'])
        print(f"Загружена лучшая модель (эп. {ckpt['epoch']}, val acc {ckpt['val_acc']:.2f}%)")

    return {
        'train_losses': train_losses,
        'val_losses': val_losses,
        'train_accs': train_accs,
        'val_accs': val_accs,
        'best_val_acc': best_val_acc,
        'best_epoch': best_epoch,
        'stopped_epoch': epoch + 1 if epochs_no_improve >= patience else num_epochs
    }


def test_model(model, test_loader, criterion, device, emotion_labels):
    model.eval()
    all_preds = []
    all_labels = []
    test_loss = 0.0

    with torch.no_grad():
        for inputs, labels in tqdm(test_loader, desc='Тестирование'):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    test_loss /= len(test_loader)
    test_acc = accuracy_score(all_labels, all_preds) * 100

    precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average=None, zero_division=0)
    _, _, f1_macro, _ = precision_recall_fscore_support(all_labels, all_preds, average='macro', zero_division=0)

    print(f"\nTest Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_acc:.2f}%")
    print(f"Macro F1-Score: {f1_macro:.4f}")

    print("\nPer-class metrics:")
    for i, lbl in emotion_labels.items():
        print(f" {lbl}: F1={f1[i]:.3f}, Prec={precision[i]:.3f}, Rec={recall[i]:.3f}")

    return all_preds, all_labels, test_loss, test_acc


def plot_confusion_matrix(y_true, y_pred, emotion_labels):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=list(emotion_labels.values()),
                yticklabels=list(emotion_labels.values()))
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()
    plt.show()


def plot_training_history(history):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    axes[0].plot(history['train_losses'], label='Train Loss')
    axes[0].plot(history['val_losses'], label='Val Loss')
    axes[0].set_title('Loss')
    axes[0].legend()
    axes[0].grid(True)

    axes[1].plot(history['train_accs'], label='Train Acc')
    axes[1].plot(history['val_accs'], label='Val Acc')
    axes[1].set_title('Accuracy')
    axes[1].legend()
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()


def main():
    print("РАСПОЗНАВАНИЕ ЭМОЦИЙ НА RAF-DB С ОККЛЮЗИЯМИ")
    print("EfficientNet-B2")

    TRAIN_DIR = r"train_occluded_50"
    VAL_DIR = r"val_original"
    TEST_DIR = r"occluded_test_dataset"

    BATCH_SIZE = 32
    LEARNING_RATE = 0.001
    NUM_EPOCHS = 40
    RANDOM_SEED = 42

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Устройство: {device}")

    torch.manual_seed(RANDOM_SEED)
    np.random.seed(RANDOM_SEED)
    random.seed(RANDOM_SEED)

    print("\n1. Загрузка данных")
    print(f"   Train (50% оклюзий): {TRAIN_DIR}")
    print(f"   Val (0% оклюзий): {VAL_DIR}")
    print(f"   Test (70% оклюзий): {TEST_DIR}")

    train_loader, val_loader, test_loader, emotion_labels = create_dataloaders_from_folders(
        train_dir=TRAIN_DIR,
        val_dir=VAL_DIR,
        test_dir=TEST_DIR,
        batch_size=BATCH_SIZE
    )

    print(f"  Train: {len(train_loader.dataset):6d} изображений")
    print(f"  Val:   {len(val_loader.dataset):6d} изображений")
    print(f"  Test:  {len(test_loader.dataset):6d} изображений")

    print(f"\n2. Создание модели (EfficientNet-B2 ImageNet)")
    model = EfficientNetEmotion(num_classes=7, pretrained=True)
    print(f"  Всего параметров: {sum(p.numel() for p in model.parameters()):,}")

    criterion = FocalLoss(gamma=1.5, alpha=None)
    optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=5e-4)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='min',
        factor=0.5,
        patience=5,
        min_lr=1e-6
    )

    print("\n3. Начало обучения")
    history = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        criterion=criterion,
        optimizer=optimizer,
        scheduler=scheduler,
        num_epochs=NUM_EPOCHS,
        device=device,
        patience=10,
        min_delta=0.001
    )

    print("\n4. Визуализация кривых обучения")
    plot_training_history(history)

    print("\n5. Тестирование на выборке с окклюзиями (70% оклюзий)")
    all_preds, all_labels, test_loss, test_acc = test_model(
        model=model,
        test_loader=test_loader,
        criterion=criterion,
        device=device,
        emotion_labels=emotion_labels
    )

    plot_confusion_matrix(all_labels, all_preds, emotion_labels)

    print("\n6. Сохранение")
    os.makedirs("results", exist_ok=True)
    torch.save({
        'model_state_dict': model.state_dict(),
        'history': history,
        'test_acc': test_acc,
    }, f"results/rafdb_efficientnet_b2_occlusion_trained.pth")
    print(f"Модель сохранена в results/rafdb_efficientnet_b2_occlusion_trained.pth")

    print("\n")
    print(f"ИТОГОВАЯ ТОЧНОСТЬ НА ТЕСТЕ (70% ОККЛЮЗИЙ): {test_acc:.2f}%")


if __name__ == "__main__":
    main()
# Out:
# РАСПОЗНАВАНИЕ ЭМОЦИЙ НА RAF-DB С ОККЛЮЗИЯМИ
# EfficientNet-B2
# Устройство: cuda
#
# 1. Загрузка данных
#    Train (50% оклюзий): train_occluded_50
#    Val (0% оклюзий): val_original
#    Test (70% оклюзий): occluded_test_dataset
#   Train:  10430 изображений
#   Val:     1841 изображений
#   Test:    3068 изображений
#
# 2. Создание модели (EfficientNet-B2 ImageNet)
# Downloading: "https://download.pytorch.org/models/efficientnet_b2_rwightman-c35c1473.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b2_rwightman-c35c1473.pth
# 100%|██████████| 35.2M/35.2M [00:00<00:00, 207MB/s]
#   Всего параметров: 8,064,009
#
# 3. Начало обучения
# Чекпоинты будут сохраняться после каждой эпохи в: ./checkpoints/
# Early stopping: patience=10, min_delta=0.001
# Epoch 1/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 1/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_001_val73.17.pth   (val acc 73.17%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 73.17% (эпоха 1)
# Epoch  1/40: train 0.7360 / 62.46% | val 0.4540 / 73.17%
# Epoch 2/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 2/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_002_val77.29.pth   (val acc 77.29%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 77.29% (эпоха 2)
# Epoch  2/40: train 0.4599 / 74.84% | val 0.3742 / 77.29%
# Epoch 3/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 3/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_003_val79.25.pth   (val acc 79.25%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 79.25% (эпоха 3)
# Epoch  3/40: train 0.3635 / 78.99% | val 0.3482 / 79.25%
# Epoch 4/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 4/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_004_val80.83.pth   (val acc 80.83%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 80.83% (эпоха 4)
# Epoch  4/40: train 0.3000 / 81.77% | val 0.3368 / 80.83%
# Epoch 5/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 5/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_005_val80.01.pth   (val acc 80.01%)
# Нет улучшения (1/10)
# Epoch  5/40: train 0.2644 / 83.05% | val 0.3636 / 80.01%
# Epoch 6/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 6/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_006_val81.10.pth   (val acc 81.10%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 81.10% (эпоха 6)
# Epoch  6/40: train 0.2234 / 85.12% | val 0.3302 / 81.10%
# Epoch 7/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 7/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_007_val80.45.pth   (val acc 80.45%)
# Нет улучшения (1/10)
# Epoch  7/40: train 0.1956 / 86.63% | val 0.3419 / 80.45%
# Epoch 8/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 8/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_008_val80.61.pth   (val acc 80.61%)
# Нет улучшения (2/10)
# Epoch  8/40: train 0.1790 / 87.97% | val 0.3715 / 80.61%
# Epoch 9/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 9/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_009_val79.52.pth   (val acc 79.52%)
# Нет улучшения (3/10)
# Epoch  9/40: train 0.1503 / 89.42% | val 0.3679 / 79.52%
# Epoch 10/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 10/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_010_val79.14.pth   (val acc 79.14%)
# Нет улучшения (4/10)
# Epoch 10/40: train 0.1348 / 90.69% | val 0.4009 / 79.14%
# Epoch 11/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 11/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_011_val79.36.pth   (val acc 79.36%)
# Нет улучшения (5/10)
# Epoch 11/40: train 0.1340 / 90.40% | val 0.3870 / 79.36%
# Epoch 12/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 12/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_012_val80.88.pth   (val acc 80.88%)
# Нет улучшения (6/10)
# Epoch 12/40: train 0.1152 / 92.02% | val 0.3564 / 80.88%
# Epoch 13/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 13/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_013_val83.76.pth   (val acc 83.76%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 83.76% (эпоха 13)
# Epoch 13/40: train 0.0523 / 95.88% | val 0.3620 / 83.76%
# Epoch 14/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 14/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_014_val83.43.pth   (val acc 83.43%)
# Нет улучшения (1/10)
# Epoch 14/40: train 0.0309 / 97.47% | val 0.3723 / 83.43%
# Epoch 15/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 15/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_015_val83.81.pth   (val acc 83.81%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 83.81% (эпоха 15)
# Epoch 15/40: train 0.0270 / 97.72% | val 0.3927 / 83.81%
# Epoch 16/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 16/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_016_val83.05.pth   (val acc 83.05%)
# Нет улучшения (1/10)
# Epoch 16/40: train 0.0266 / 97.86% | val 0.4043 / 83.05%
# Epoch 17/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 17/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_017_val82.40.pth   (val acc 82.40%)
# Нет улучшения (2/10)
# Epoch 17/40: train 0.0271 / 97.87% | val 0.4681 / 82.40%
# Epoch 18/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 18/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_018_val82.35.pth   (val acc 82.35%)
# Нет улучшения (3/10)
# Epoch 18/40: train 0.0276 / 97.95% | val 0.4502 / 82.35%
# Epoch 19/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 19/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_019_val83.92.pth   (val acc 83.92%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 83.92% (эпоха 19)
# Epoch 19/40: train 0.0150 / 98.76% | val 0.4089 / 83.92%
# Epoch 20/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 20/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_020_val84.68.pth   (val acc 84.68%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 84.68% (эпоха 20)
# Epoch 20/40: train 0.0105 / 99.11% | val 0.4212 / 84.68%
# Epoch 21/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 21/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_021_val84.03.pth   (val acc 84.03%)
# Нет улучшения (1/10)
# Epoch 21/40: train 0.0100 / 99.18% | val 0.4281 / 84.03%
# Epoch 22/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 22/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_022_val83.81.pth   (val acc 83.81%)
# Нет улучшения (2/10)
# Epoch 22/40: train 0.0100 / 99.19% | val 0.4582 / 83.81%
# Epoch 23/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 23/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_023_val83.98.pth   (val acc 83.98%)
# Нет улучшения (3/10)
# Epoch 23/40: train 0.0063 / 99.48% | val 0.4685 / 83.98%
# Epoch 24/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 24/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_024_val83.22.pth   (val acc 83.22%)
# Нет улучшения (4/10)
# Epoch 24/40: train 0.0074 / 99.33% | val 0.4946 / 83.22%
# Epoch 25/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 25/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_025_val83.54.pth   (val acc 83.54%)
# Нет улучшения (5/10)
# Epoch 25/40: train 0.0067 / 99.49% | val 0.4783 / 83.54%
# Epoch 26/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 26/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_026_val84.79.pth   (val acc 84.79%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 84.79% (эпоха 26)
# Epoch 26/40: train 0.0029 / 99.72% | val 0.4830 / 84.79%
# Epoch 27/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 27/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_027_val84.74.pth   (val acc 84.74%)
# Нет улучшения (1/10)
# Epoch 27/40: train 0.0024 / 99.84% | val 0.4834 / 84.74%
# Epoch 28/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 28/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_028_val84.68.pth   (val acc 84.68%)
# Нет улучшения (2/10)
# Epoch 28/40: train 0.0034 / 99.81% | val 0.4827 / 84.68%
# Epoch 29/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 29/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_029_val84.14.pth   (val acc 84.14%)
# Нет улучшения (3/10)
# Epoch 29/40: train 0.0029 / 99.77% | val 0.5044 / 84.14%
# Epoch 30/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 30/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_030_val84.14.pth   (val acc 84.14%)
# Нет улучшения (4/10)
# Epoch 30/40: train 0.0056 / 99.62% | val 0.4820 / 84.14%
# Epoch 31/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 31/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_031_val85.28.pth   (val acc 85.28%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 85.28% (эпоха 31)
# Epoch 31/40: train 0.0035 / 99.72% | val 0.4613 / 85.28%
# Epoch 32/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 32/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_032_val84.63.pth   (val acc 84.63%)
# Нет улучшения (1/10)
# Epoch 32/40: train 0.0026 / 99.80% | val 0.4625 / 84.63%
# Epoch 33/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 33/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_033_val84.85.pth   (val acc 84.85%)
# Нет улучшения (2/10)
# Epoch 33/40: train 0.0016 / 99.89% | val 0.4893 / 84.85%
# Epoch 34/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 34/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_034_val85.28.pth   (val acc 85.28%)
# Нет улучшения (3/10)
# Epoch 34/40: train 0.0013 / 99.93% | val 0.4891 / 85.28%
# Epoch 35/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 35/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_035_val84.95.pth   (val acc 84.95%)
# Нет улучшения (4/10)
# Epoch 35/40: train 0.0011 / 99.91% | val 0.4922 / 84.95%
# Epoch 36/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 36/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_036_val85.12.pth   (val acc 85.12%)
# Нет улучшения (5/10)
# Epoch 36/40: train 0.0007 / 99.97% | val 0.5047 / 85.12%
# Epoch 37/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 37/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_037_val84.63.pth   (val acc 84.63%)
# Нет улучшения (6/10)
# Epoch 37/40: train 0.0012 / 99.90% | val 0.4899 / 84.63%
# Epoch 38/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 38/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_038_val84.95.pth   (val acc 84.95%)
# Нет улучшения (7/10)
# Epoch 38/40: train 0.0013 / 99.94% | val 0.4943 / 84.95%
# Epoch 39/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 39/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_039_val84.52.pth   (val acc 84.52%)
# Нет улучшения (8/10)
# Epoch 39/40: train 0.0014 / 99.90% | val 0.5053 / 84.52%
# Epoch 40/40 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 40/40 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_040_val84.63.pth   (val acc 84.63%)
# Нет улучшения (9/10)
# Epoch 40/40: train 0.0010 / 99.90% | val 0.5047 / 84.63%
#
# Загружена лучшая модель (эп. 31, val acc 85.28%)
#
# 4. Визуализация кривых обучения
# 5. Тестирование на выборке с окклюзиями (70% оклюзий)
# Тестирование:   0%|          | 0/96 [00:00<?, ?it/s]
# Test Loss: 0.4600
# Test Accuracy: 84.09%
# Macro F1-Score: 0.7560
#
# Per-class metrics:
#  Surprise: F1=0.845, Prec=0.854, Rec=0.836
#  Fear: F1=0.603, Prec=0.661, Rec=0.554
#  Disgust: F1=0.539, Prec=0.569, Rec=0.512
#  Happiness: F1=0.931, Prec=0.931, Rec=0.931
#  Sadness: F1=0.801, Prec=0.819, Rec=0.785
#  Anger: F1=0.749, Prec=0.752, Rec=0.747
#  Neutral: F1=0.823, Prec=0.792, Rec=0.857
# 6. Сохранение
# Модель сохранена в results/rafdb_efficientnet_b2_occlusion_trained.pth
#
#
# ИТОГОВАЯ ТОЧНОСТЬ НА ТЕСТЕ (70% ОККЛЮЗИЙ): 84.09%
