# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torchvision.models as models
import numpy as np
from sklearn.metrics import confusion_matrix, accuracy_score, precision_recall_fscore_support
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.auto import tqdm
import warnings
import os
import random
from PIL import Image
from pathlib import Path
import copy
import pickle
import timm
warnings.filterwarnings('ignore')


class FocalLoss(nn.Module):
    def __init__(self, gamma=1.5, alpha=None, reduction='mean'):
        super().__init__()
        self.gamma = gamma
        self.alpha = alpha
        self.reduction = reduction

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = (1 - pt) ** self.gamma * ce_loss

        if self.alpha is not None:
            alpha_t = self.alpha[targets]
            focal_loss = alpha_t * focal_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        return focal_loss.sum()


class ViTEmotion(nn.Module):
    def __init__(self, num_classes=7, pretrained=True):
        super().__init__()
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        self.backbone = timm.create_model(
            'vit_small_patch16_224',
            pretrained=pretrained,
            num_classes=num_classes,
            drop_path_rate=0.1
        )

        self.to(self.device)

    def forward(self, x):
        x = x.to(self.device)
        return self.backbone(x)


class SimpleDataset(Dataset):
    def __init__(self, root_dir):
        self.root_dir = Path(root_dir)
        self.images = []
        self.labels = []
        self._load_data()

        self.transform = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225]),
        ])

    def _load_data(self):
        for class_folder in sorted(self.root_dir.iterdir()):
            if not class_folder.is_dir():
                continue
            try:
                class_idx = int(class_folder.name)
                if class_idx not in range(1, 8):
                    continue
                label = class_idx - 1
                for img_path in class_folder.glob('*.[jp][pn]g'):
                    self.images.append(str(img_path))
                    self.labels.append(label)
            except Exception as e:
                print(f"Ошибка при загрузке {class_folder}: {e}")
                continue

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = self.labels[idx]

        image = Image.open(img_path).convert('RGB')
        image = self.transform(image)

        return image, torch.tensor(label, dtype=torch.long)


class SimpleDatasetWithAugmentation(Dataset):
    def __init__(self, root_dir):
        self.root_dir = Path(root_dir)
        self.images = []
        self.labels = []
        self._load_data()

        self.transform = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomRotation(degrees=15),
            transforms.RandomAffine(degrees=0, translate=(0.1, 0.1), scale=(0.9, 1.1)),
            transforms.RandAugment(magnitude=7, num_ops=2),
            transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225]),
        ])

    def _load_data(self):
        for class_folder in sorted(self.root_dir.iterdir()):
            if not class_folder.is_dir():
                continue
            try:
                class_idx = int(class_folder.name)
                if class_idx not in range(1, 8):
                    continue
                label = class_idx - 1
                for img_path in class_folder.glob('*.[jp][pn]g'):
                    self.images.append(str(img_path))
                    self.labels.append(label)
            except Exception as e:
                print(f"Ошибка: {e}")
                continue

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = self.labels[idx]

        image = Image.open(img_path).convert('RGB')
        image = self.transform(image)

        return image, torch.tensor(label, dtype=torch.long)


def create_dataloaders_from_folders(train_dir, val_dir, test_dir, batch_size=32):
    emotion_labels = {
        0: 'Surprise', 1: 'Fear', 2: 'Disgust',
        3: 'Happiness', 4: 'Sadness', 5: 'Anger', 6: 'Neutral'
    }

    train_dataset = SimpleDatasetWithAugmentation(train_dir)
    val_dataset = SimpleDataset(val_dir)
    test_dataset = SimpleDataset(test_dir)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0)

    return train_loader, val_loader, test_loader, emotion_labels


def train_model(model, train_loader, val_loader, criterion, optimizer,
                scheduler, num_epochs=30, device='cuda',
                patience=10, min_delta=0.001,
                checkpoint_dir="checkpoints"):

    os.makedirs(checkpoint_dir, exist_ok=True)

    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []

    best_val_acc = -float('inf')
    epochs_no_improve = 0
    best_epoch = 0

    print(f"Чекпоинты будут сохраняться после каждой эпохи в: ./{checkpoint_dir}/")
    print(f"Early stopping: patience={patience}, min_delta={min_delta}\n")

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        train_pbar = tqdm(train_loader, desc=f'Epoch {epoch+1}/{num_epochs} [Train]')

        for inputs, labels in train_pbar:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            train_pbar.set_postfix(Loss=f'{loss.item():.4f}', Acc=f'{100.*correct/total:.2f}%')

        train_loss = running_loss / len(train_loader)
        train_acc = 100. * correct / total
        train_losses.append(train_loss)
        train_accs.append(train_acc)

        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0

        with torch.no_grad():
            val_pbar = tqdm(val_loader, desc=f'Epoch {epoch+1}/{num_epochs} [Val]  ')

            for inputs, labels in val_pbar:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item()
                _, predicted = outputs.max(1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                val_pbar.set_postfix(Loss=f'{loss.item():.4f}', Acc=f'{100.*correct/total:.2f}%')

        val_loss = val_loss / len(val_loader)
        val_acc = 100. * correct / total
        val_losses.append(val_loss)
        val_accs.append(val_acc)

        if scheduler is not None:
            scheduler.step(val_loss)

        epoch_file = f"epoch_{epoch+1:03d}_val{val_acc:.2f}.pth"
        save_path = os.path.join(checkpoint_dir, epoch_file)

        torch.save({
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict() if scheduler else None,
            'train_loss': train_loss,
            'val_loss': val_loss,
            'train_acc': train_acc,
            'val_acc': val_acc,
        }, save_path)

        print(f"Сохранено: {epoch_file}   (val acc {val_acc:.2f}%)")

        improved = val_acc > best_val_acc + min_delta

        if improved:
            best_val_acc = val_acc
            best_epoch = epoch + 1
            epochs_no_improve = 0

            best_path = os.path.join(checkpoint_dir, "best_model.pth")
            torch.save({
                'epoch': best_epoch,
                'model_state_dict': model.state_dict(),
                'val_acc': best_val_acc,
            }, best_path)

            print(f"НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc {val_acc:.2f}% (эпоха {best_epoch})")
        else:
            epochs_no_improve += 1
            print(f"Нет улучшения ({epochs_no_improve}/{patience})")

            if epochs_no_improve >= patience:
                print(f"\nEarly stopping на эпохе {epoch+1}")
                print(f"Лучшая val acc: {best_val_acc:.2f}% (эпоха {best_epoch})")
                break

        print(f"Epoch {epoch+1:2d}/{num_epochs}: "
              f"train {train_loss:.4f} / {train_acc:5.2f}% | "
              f"val {val_loss:.4f} / {val_acc:5.2f}%\n")

    best_path = os.path.join(checkpoint_dir, "best_model.pth")
    if os.path.exists(best_path):
        ckpt = torch.load(best_path, map_location=device)
        model.load_state_dict(ckpt['model_state_dict'])
        print(f"Загружена лучшая модель (эп. {ckpt['epoch']}, val acc {ckpt['val_acc']:.2f}%)")

    return {
        'train_losses': train_losses,
        'val_losses': val_losses,
        'train_accs': train_accs,
        'val_accs': val_accs,
        'best_val_acc': best_val_acc,
        'best_epoch': best_epoch,
        'stopped_epoch': epoch + 1 if epochs_no_improve >= patience else num_epochs
    }


def test_model(model, test_loader, criterion, device, emotion_labels):
    model.eval()
    all_preds = []
    all_labels = []
    test_loss = 0.0

    with torch.no_grad():
        for inputs, labels in tqdm(test_loader, desc='Тестирование'):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    test_loss /= len(test_loader)
    test_acc = accuracy_score(all_labels, all_preds) * 100

    precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average=None, zero_division=0)
    _, _, f1_macro, _ = precision_recall_fscore_support(all_labels, all_preds, average='macro', zero_division=0)

    print(f"\nTest Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_acc:.2f}%")
    print(f"Macro F1-Score: {f1_macro:.4f}")

    print("\nPer-class metrics:")
    for i, lbl in emotion_labels.items():
        print(f" {lbl}: F1={f1[i]:.3f}, Prec={precision[i]:.3f}, Rec={recall[i]:.3f}")

    return all_preds, all_labels, test_loss, test_acc


def plot_confusion_matrix(y_true, y_pred, emotion_labels):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=list(emotion_labels.values()),
                yticklabels=list(emotion_labels.values()))
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()
    plt.show()


def plot_training_history(history):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    axes[0].plot(history['train_losses'], label='Train Loss')
    axes[0].plot(history['val_losses'], label='Val Loss')
    axes[0].set_title('Loss')
    axes[0].legend()
    axes[0].grid(True)

    axes[1].plot(history['train_accs'], label='Train Acc')
    axes[1].plot(history['val_accs'], label='Val Acc')
    axes[1].set_title('Accuracy')
    axes[1].legend()
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()


def main():
    print("РАСПОЗНАВАНИЕ ЭМОЦИЙ НА RAF-DB С ОККЛЮЗИЯМИ")
    print("ViT-Small/16")

    TRAIN_DIR = r"train_occluded_50"
    VAL_DIR = r"val_original"
    TEST_DIR = r"occluded_test_dataset"

    CHECKPOINT_DIR = "checkpoints"

    BATCH_SIZE = 64
    LEARNING_RATE = 0.0002
    NUM_EPOCHS = 40
    RANDOM_SEED = 42

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Устройство: {device}")

    torch.manual_seed(RANDOM_SEED)
    np.random.seed(RANDOM_SEED)
    random.seed(RANDOM_SEED)

    print("\n1. Загрузка данных")
    print(f"   Train (50% оклюзий): {TRAIN_DIR}")
    print(f"   Val (0% оклюзий): {VAL_DIR}")
    print(f"   Test (70% оклюзий): {TEST_DIR}")

    train_loader, val_loader, test_loader, emotion_labels = create_dataloaders_from_folders(
        train_dir=TRAIN_DIR,
        val_dir=VAL_DIR,
        test_dir=TEST_DIR,
        batch_size=BATCH_SIZE
    )

    print(f"  Train: {len(train_loader.dataset):6d} изображений")
    print(f"  Val:   {len(val_loader.dataset):6d} изображений")
    print(f"  Test:  {len(test_loader.dataset):6d} изображений")

    print(f"\n2. Создание модели (ViT-Small/16 ImageNet)")
    model = ViTEmotion(num_classes=7, pretrained=True)
    print(f"  Всего параметров: {sum(p.numel() for p in model.parameters()):,}")

    criterion = FocalLoss(gamma=1.5, alpha=None)
    optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=5e-4)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='min',
        factor=0.5,
        patience=5,
        min_lr=1e-6
    )

    print("\n3. Начало обучения")
    history = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        criterion=criterion,
        optimizer=optimizer,
        scheduler=scheduler,
        num_epochs=NUM_EPOCHS,
        device=device,
        patience=10,
        min_delta=0.001,
        checkpoint_dir=CHECKPOINT_DIR
    )

    print("\n4. Визуализация кривых обучения")
    plot_training_history(history)

    print("\n5. Тестирование на выборке с окклюзиями (70% оклюзий)")
    all_preds, all_labels, test_loss, test_acc = test_model(
        model=model,
        test_loader=test_loader,
        criterion=criterion,
        device=device,
        emotion_labels=emotion_labels
    )

    plot_confusion_matrix(all_labels, all_preds, emotion_labels)

    print("\n6. Сохранение")
    os.makedirs("results", exist_ok=True)
    torch.save({
        'model_state_dict': model.state_dict(),
        'history': history,
        'test_acc': test_acc,
    }, f"results/rafdb_vit_small_occlusion_trained.pth")
    print(f"Модель сохранена в results/rafdb_vit_small_occlusion_trained.pth")

    print("\n")
    print(f"ИТОГОВАЯ ТОЧНОСТЬ НА ТЕСТЕ (70% ОККЛЮЗИЙ): {test_acc:.2f}%")


if __name__ == "__main__":
    main()
# Out:
# РАСПОЗНАВАНИЕ ЭМОЦИЙ НА RAF-DB С ОККЛЮЗИЯМИ
# ViT-Small/16
# Устройство: cuda
#
# 1. Загрузка данных
#    Train (50% оклюзий): train_occluded_50
#    Val (0% оклюзий): val_original
#    Test (70% оклюзий): occluded_test_dataset
#   Train:  10430 изображений
#   Val:     1841 изображений
#   Test:    3068 изображений
#
# 2. Создание модели (ViT-Small/16 ImageNet)
#   Всего параметров: 21,668,359
#
# 3. Начало обучения
# Чекпоинты будут сохраняться после каждой эпохи в: ./checkpoints/
# Early stopping: patience=10, min_delta=0.001
# Epoch 1/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 1/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_001_val50.52.pth   (val acc 50.52%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 50.52% (эпоха 1)
# Epoch  1/40: train 1.2051 / 38.74% | val 0.9555 / 50.52%
# Epoch 2/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 2/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_002_val69.53.pth   (val acc 69.53%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 69.53% (эпоха 2)
# Epoch  2/40: train 0.8184 / 57.70% | val 0.5517 / 69.53%
# Epoch 3/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 3/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_003_val74.09.pth   (val acc 74.09%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 74.09% (эпоха 3)
# Epoch  3/40: train 0.5935 / 68.11% | val 0.4261 / 74.09%
# Epoch 4/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 4/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_004_val77.89.pth   (val acc 77.89%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 77.89% (эпоха 4)
# Epoch  4/40: train 0.5046 / 71.84% | val 0.3709 / 77.89%
# Epoch 5/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 5/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_005_val79.09.pth   (val acc 79.09%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 79.09% (эпоха 5)
# Epoch  5/40: train 0.4462 / 74.26% | val 0.3565 / 79.09%
# Epoch 6/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 6/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_006_val78.76.pth   (val acc 78.76%)
# Нет улучшения (1/10)
# Epoch  6/40: train 0.3959 / 76.84% | val 0.3733 / 78.76%
# Epoch 7/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 7/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_007_val76.59.pth   (val acc 76.59%)
# Нет улучшения (2/10)
# Epoch  7/40: train 0.3691 / 78.33% | val 0.3907 / 76.59%
# Epoch 8/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 8/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_008_val80.99.pth   (val acc 80.99%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 80.99% (эпоха 8)
# Epoch  8/40: train 0.3468 / 78.98% | val 0.3087 / 80.99%
# Epoch 9/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 9/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_009_val78.16.pth   (val acc 78.16%)
# Нет улучшения (1/10)
# Epoch  9/40: train 0.3160 / 80.97% | val 0.3717 / 78.16%
# Epoch 10/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 10/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_010_val79.30.pth   (val acc 79.30%)
# Нет улучшения (2/10)
# Epoch 10/40: train 0.3053 / 81.03% | val 0.3289 / 79.30%
# Epoch 11/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 11/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_011_val81.97.pth   (val acc 81.97%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 81.97% (эпоха 11)
# Epoch 11/40: train 0.2685 / 83.00% | val 0.3034 / 81.97%
# Epoch 12/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 12/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_012_val83.49.pth   (val acc 83.49%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 83.49% (эпоха 12)
# Epoch 12/40: train 0.2554 / 83.26% | val 0.2854 / 83.49%
# Epoch 13/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 13/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_013_val83.27.pth   (val acc 83.27%)
# Нет улучшения (1/10)
# Epoch 13/40: train 0.2348 / 84.67% | val 0.3009 / 83.27%
# Epoch 14/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 14/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_014_val82.35.pth   (val acc 82.35%)
# Нет улучшения (2/10)
# Epoch 14/40: train 0.2254 / 85.00% | val 0.3373 / 82.35%
# Epoch 15/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 15/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_015_val80.45.pth   (val acc 80.45%)
# Нет улучшения (3/10)
# Epoch 15/40: train 0.2076 / 86.15% | val 0.3630 / 80.45%
# Epoch 16/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 16/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_016_val82.29.pth   (val acc 82.29%)
# Нет улучшения (4/10)
# Epoch 16/40: train 0.1952 / 86.97% | val 0.3281 / 82.29%
# Epoch 17/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 17/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_017_val81.31.pth   (val acc 81.31%)
# Нет улучшения (5/10)
# Epoch 17/40: train 0.1751 / 87.86% | val 0.3726 / 81.31%
# Epoch 18/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 18/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_018_val82.29.pth   (val acc 82.29%)
# Нет улучшения (6/10)
# Epoch 18/40: train 0.1765 / 88.09% | val 0.3314 / 82.29%
# Epoch 19/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 19/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_019_val83.92.pth   (val acc 83.92%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 83.92% (эпоха 19)
# Epoch 19/40: train 0.1115 / 91.69% | val 0.3293 / 83.92%
# Epoch 20/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 20/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_020_val84.74.pth   (val acc 84.74%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 84.74% (эпоха 20)
# Epoch 20/40: train 0.0967 / 92.84% | val 0.3214 / 84.74%
# Epoch 21/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 21/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_021_val83.81.pth   (val acc 83.81%)
# Нет улучшения (1/10)
# Epoch 21/40: train 0.0868 / 93.26% | val 0.3397 / 83.81%
# Epoch 22/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 22/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_022_val84.08.pth   (val acc 84.08%)
# Нет улучшения (2/10)
# Epoch 22/40: train 0.0744 / 94.53% | val 0.3313 / 84.08%
# Epoch 23/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 23/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_023_val84.19.pth   (val acc 84.19%)
# Нет улучшения (3/10)
# Epoch 23/40: train 0.0766 / 94.30% | val 0.3747 / 84.19%
# Epoch 24/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 24/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_024_val83.22.pth   (val acc 83.22%)
# Нет улучшения (4/10)
# Epoch 24/40: train 0.0766 / 94.29% | val 0.3692 / 83.22%
# Epoch 25/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 25/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_025_val83.76.pth   (val acc 83.76%)
# Нет улучшения (5/10)
# Epoch 25/40: train 0.0540 / 96.06% | val 0.3732 / 83.76%
# Epoch 26/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 26/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_026_val84.57.pth   (val acc 84.57%)
# Нет улучшения (6/10)
# Epoch 26/40: train 0.0508 / 96.41% | val 0.3500 / 84.57%
# Epoch 27/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 27/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_027_val85.28.pth   (val acc 85.28%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 85.28% (эпоха 27)
# Epoch 27/40: train 0.0432 / 96.74% | val 0.3729 / 85.28%
# Epoch 28/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 28/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_028_val83.87.pth   (val acc 83.87%)
# Нет улучшения (1/10)
# Epoch 28/40: train 0.0386 / 97.13% | val 0.3930 / 83.87%
# Epoch 29/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 29/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_029_val84.36.pth   (val acc 84.36%)
# Нет улучшения (2/10)
# Epoch 29/40: train 0.0442 / 96.67% | val 0.4130 / 84.36%
# Epoch 30/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 30/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_030_val85.17.pth   (val acc 85.17%)
# Нет улучшения (3/10)
# Epoch 30/40: train 0.0447 / 96.59% | val 0.3645 / 85.17%
# Epoch 31/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 31/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_031_val84.90.pth   (val acc 84.90%)
# Нет улучшения (4/10)
# Epoch 31/40: train 0.0290 / 97.87% | val 0.4003 / 84.90%
# Epoch 32/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 32/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_032_val85.01.pth   (val acc 85.01%)
# Нет улучшения (5/10)
# Epoch 32/40: train 0.0325 / 97.76% | val 0.4064 / 85.01%
# Epoch 33/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 33/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_033_val85.17.pth   (val acc 85.17%)
# Нет улучшения (6/10)
# Epoch 33/40: train 0.0281 / 97.89% | val 0.4109 / 85.17%
# Epoch 34/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 34/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_034_val85.17.pth   (val acc 85.17%)
# Нет улучшения (7/10)
# Epoch 34/40: train 0.0277 / 97.86% | val 0.4013 / 85.17%
# Epoch 35/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 35/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_035_val85.44.pth   (val acc 85.44%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 85.44% (эпоха 35)
# Epoch 35/40: train 0.0276 / 98.02% | val 0.4077 / 85.44%
# Epoch 36/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 36/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_036_val84.74.pth   (val acc 84.74%)
# Нет улучшения (1/10)
# Epoch 36/40: train 0.0260 / 98.05% | val 0.4332 / 84.74%
# Epoch 37/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 37/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_037_val84.85.pth   (val acc 84.85%)
# Нет улучшения (2/10)
# Epoch 37/40: train 0.0256 / 98.12% | val 0.4011 / 84.85%
# Epoch 38/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 38/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_038_val85.01.pth   (val acc 85.01%)
# Нет улучшения (3/10)
# Epoch 38/40: train 0.0263 / 97.98% | val 0.4073 / 85.01%
# Epoch 39/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 39/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_039_val85.33.pth   (val acc 85.33%)
# Нет улучшения (4/10)
# Epoch 39/40: train 0.0203 / 98.57% | val 0.4088 / 85.33%
# Epoch 40/40 [Train]:   0%|          | 0/163 [00:00<?, ?it/s]
# Epoch 40/40 [Val]  :   0%|          | 0/29 [00:00<?, ?it/s]
# Сохранено: epoch_040_val85.12.pth   (val acc 85.12%)
# Нет улучшения (5/10)
# Epoch 40/40: train 0.0198 / 98.47% | val 0.4177 / 85.12%
#
# Загружена лучшая модель (эп. 35, val acc 85.44%)
#
# 4. Визуализация кривых обучения
# 5. Тестирование на выборке с окклюзиями (70% оклюзий)
# Тестирование:   0%|          | 0/48 [00:00<?, ?it/s]
# Test Loss: 0.4618
# Test Accuracy: 83.83%
# Macro F1-Score: 0.7573
#
# Per-class metrics:
#  Surprise: F1=0.819, Prec=0.806, Rec=0.833
#  Fear: F1=0.597, Prec=0.667, Rec=0.541
#  Disgust: F1=0.558, Prec=0.581, Rec=0.537
#  Happiness: F1=0.933, Prec=0.954, Rec=0.913
#  Sadness: F1=0.831, Prec=0.841, Rec=0.820
#  Anger: F1=0.764, Prec=0.724, Rec=0.809
#  Neutral: F1=0.799, Prec=0.767, Rec=0.834
# 6. Сохранение
# Модель сохранена в results/rafdb_vit_small_occlusion_trained.pth
#
#
# ИТОГОВАЯ ТОЧНОСТЬ НА ТЕСТЕ (70% ОККЛЮЗИЙ): 83.83%
