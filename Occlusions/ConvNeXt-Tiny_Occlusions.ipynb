# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torchvision.models as models
import numpy as np
from sklearn.metrics import confusion_matrix, accuracy_score, precision_recall_fscore_support
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.auto import tqdm
import warnings
import os
import random
from PIL import Image
from pathlib import Path
import copy
import pickle
warnings.filterwarnings('ignore')


class FocalLoss(nn.Module):
    def __init__(self, gamma=1.5, alpha=None, reduction='mean'):
        super().__init__()
        self.gamma = gamma
        self.alpha = alpha
        self.reduction = reduction

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = (1 - pt) ** self.gamma * ce_loss

        if self.alpha is not None:
            alpha_t = self.alpha[targets]
            focal_loss = alpha_t * focal_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        return focal_loss.sum()


class ConvNeXtEmotion(nn.Module):
    def __init__(self, num_classes=7, pretrained=True):
        super().__init__()
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        weights = models.ConvNeXt_Tiny_Weights.IMAGENET1K_V1 if pretrained else None
        self.backbone = models.convnext_tiny(weights=weights)

        in_features = 768

        self.backbone.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.LayerNorm(in_features),
            nn.Dropout(p=0.35),
            nn.Linear(in_features, 512),
            nn.GELU(),
            nn.Dropout(p=0.2),
            nn.Linear(512, num_classes)
        )

        self.to(self.device)

    def forward(self, x):
        return self.backbone(x)


class SimpleDataset(Dataset):
    def __init__(self, root_dir):
        self.root_dir = Path(root_dir)
        self.images = []
        self.labels = []
        self._load_data()

        self.transform = transforms.Compose([
                transforms.Resize(256),
                transforms.CenterCrop(224),
                transforms.ToTensor(),
                transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225]),
            ])

    def _load_data(self):
        for class_folder in sorted(self.root_dir.iterdir()):
            if not class_folder.is_dir():
                continue
            try:
                class_idx = int(class_folder.name)
                if class_idx not in range(1, 8):
                    continue
                label = class_idx - 1
                for img_path in class_folder.glob('*.[jp][pn]g'):
                    self.images.append(str(img_path))
                    self.labels.append(label)
            except Exception as e:
                print(f"Ошибка при загрузке {class_folder}: {e}")
                continue

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = self.labels[idx]

        image = Image.open(img_path).convert('RGB')
        image = self.transform(image)

        return image, torch.tensor(label, dtype=torch.long)


class SimpleDatasetWithAugmentation(Dataset):
    def __init__(self, root_dir):
        self.root_dir = Path(root_dir)
        self.images = []
        self.labels = []
        self._load_data()

        self.transform = transforms.Compose([
                transforms.RandomResizedCrop(224, scale=(0.82, 1.0), ratio=(0.9, 1.1)),
                transforms.RandomHorizontalFlip(p=0.5),
                transforms.RandomRotation(degrees=12),
                transforms.RandomApply([
                    transforms.ColorJitter(brightness=0.12, contrast=0.12, saturation=0.08)
                ], p=0.6),
                transforms.ToTensor(),
                transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225]),
                transforms.RandomErasing(p=0.25,
                                         scale=(0.02, 0.15),
                                         ratio=(0.3, 3.3),
                                         value=0)
            ])

    def _load_data(self):
        for class_folder in sorted(self.root_dir.iterdir()):
            if not class_folder.is_dir():
                continue
            try:
                class_idx = int(class_folder.name)
                if class_idx not in range(1, 8):
                    continue
                label = class_idx - 1
                for img_path in class_folder.glob('*.[jp][pn]g'):
                    self.images.append(str(img_path))
                    self.labels.append(label)
            except Exception as e:
                print(f"Ошибка: {e}")
                continue

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = self.labels[idx]

        image = Image.open(img_path).convert('RGB')
        image = self.transform(image)

        return image, torch.tensor(label, dtype=torch.long)


def create_dataloaders_from_folders(train_dir, val_dir, test_dir, batch_size=32):
    emotion_labels = {
        0: 'Surprise', 1: 'Fear', 2: 'Disgust',
        3: 'Happiness', 4: 'Sadness', 5: 'Anger', 6: 'Neutral'
    }

    train_dataset = SimpleDatasetWithAugmentation(train_dir)
    val_dataset = SimpleDataset(val_dir)
    test_dataset = SimpleDataset(test_dir)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0)

    return train_loader, val_loader, test_loader, emotion_labels


def train_model(model, train_loader, val_loader, criterion, optimizer,
                scheduler, num_epochs=50, device='cuda',
                patience=12, min_delta=0.001,
                checkpoint_dir="ConvNeXt"):

    os.makedirs(checkpoint_dir, exist_ok=True)

    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []

    best_val_acc = -float('inf')
    epochs_no_improve = 0
    best_epoch = 0

    print(f"Чекпоинты будут сохраняться после каждой эпохи в: ./{checkpoint_dir}/")
    print(f"Early stopping: patience={patience}, min_delta={min_delta}\n")

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        train_pbar = tqdm(train_loader, desc=f'Epoch {epoch+1}/{num_epochs} [Train]')

        for inputs, labels in train_pbar:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            train_pbar.set_postfix(Loss=f'{loss.item():.4f}', Acc=f'{100.*correct/total:.2f}%')

        train_loss = running_loss / len(train_loader)
        train_acc = 100. * correct / total
        train_losses.append(train_loss)
        train_accs.append(train_acc)

        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0

        with torch.no_grad():
            val_pbar = tqdm(val_loader, desc=f'Epoch {epoch+1}/{num_epochs} [Val]  ')

            for inputs, labels in val_pbar:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item()
                _, predicted = outputs.max(1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                val_pbar.set_postfix(Loss=f'{loss.item():.4f}', Acc=f'{100.*correct/total:.2f}%')

        val_loss = val_loss / len(val_loader)
        val_acc = 100. * correct / total
        val_losses.append(val_loss)
        val_accs.append(val_acc)

        if scheduler is not None:
            scheduler.step(val_loss)

        epoch_file = f"epoch_{epoch+1:03d}_val{val_acc:.2f}.pth"
        save_path = os.path.join(checkpoint_dir, epoch_file)

        torch.save({
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict() if scheduler else None,
            'train_loss': train_loss,
            'val_loss': val_loss,
            'train_acc': train_acc,
            'val_acc': val_acc,
        }, save_path)

        print(f"Сохранено: {epoch_file}   (val acc {val_acc:.2f}%)")

        improved = val_acc > best_val_acc + min_delta

        if improved:
            best_val_acc = val_acc
            best_epoch = epoch + 1
            epochs_no_improve = 0

            best_path = os.path.join(checkpoint_dir, "best_model.pth")
            torch.save({
                'epoch': best_epoch,
                'model_state_dict': model.state_dict(),
                'val_acc': best_val_acc,
            }, best_path)

            print(f"НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc {val_acc:.2f}% (эпоха {best_epoch})")
        else:
            epochs_no_improve += 1
            print(f"Нет улучшения ({epochs_no_improve}/{patience})")

            if epochs_no_improve >= patience:
                print(f"\nEarly stopping на эпохе {epoch+1}")
                print(f"Лучшая val acc: {best_val_acc:.2f}% (эпоха {best_epoch})")
                break

        print(f"Epoch {epoch+1:2d}/{num_epochs}: "
              f"train {train_loss:.4f} / {train_acc:5.2f}% | "
              f"val {val_loss:.4f} / {val_acc:5.2f}%\n")

    best_path = os.path.join(checkpoint_dir, "best_model.pth")
    if os.path.exists(best_path):
        ckpt = torch.load(best_path, map_location=device)
        model.load_state_dict(ckpt['model_state_dict'])
        print(f"Загружена лучшая модель (эп. {ckpt['epoch']}, val acc {ckpt['val_acc']:.2f}%)")

    return {
        'train_losses': train_losses,
        'val_losses': val_losses,
        'train_accs': train_accs,
        'val_accs': val_accs,
        'best_val_acc': best_val_acc,
        'best_epoch': best_epoch,
        'stopped_epoch': epoch + 1 if epochs_no_improve >= patience else num_epochs
    }


def test_model(model, test_loader, criterion, device, emotion_labels):
    model.eval()
    all_preds = []
    all_labels = []
    test_loss = 0.0

    with torch.no_grad():
        for inputs, labels in tqdm(test_loader, desc='Тестирование'):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    test_loss /= len(test_loader)
    test_acc = accuracy_score(all_labels, all_preds) * 100

    precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average=None, zero_division=0)
    _, _, f1_macro, _ = precision_recall_fscore_support(all_labels, all_preds, average='macro', zero_division=0)

    print(f"\nTest Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_acc:.2f}%")
    print(f"Macro F1-Score: {f1_macro:.4f}")

    print("\nPer-class metrics:")
    for i, lbl in emotion_labels.items():
        print(f" {lbl}: F1={f1[i]:.3f}, Prec={precision[i]:.3f}, Rec={recall[i]:.3f}")

    return all_preds, all_labels, test_loss, test_acc


def plot_confusion_matrix(y_true, y_pred, emotion_labels):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=list(emotion_labels.values()),
                yticklabels=list(emotion_labels.values()))
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()
    plt.show()


def plot_training_history(history):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    axes[0].plot(history['train_losses'], label='Train Loss')
    axes[0].plot(history['val_losses'], label='Val Loss')
    axes[0].set_title('Loss')
    axes[0].legend()
    axes[0].grid(True)

    axes[1].plot(history['train_accs'], label='Train Acc')
    axes[1].plot(history['val_accs'], label='Val Acc')
    axes[1].set_title('Accuracy')
    axes[1].legend()
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()


def main():
    print("РАСПОЗНАВАНИЕ ЭМОЦИЙ НА RAF-DB С ОККЛЮЗИЯМИ")
    print("ConvNeXt-Tiny")

    TRAIN_DIR = r"train_occluded_50"
    VAL_DIR = r"val_original"
    TEST_DIR = r"occluded_test_dataset"

    CHECKPOINT_DIR = "checkpoints_convnext_tiny"

    BATCH_SIZE = 32
    LEARNING_RATE = 5e-5
    NUM_EPOCHS = 50
    RANDOM_SEED = 42

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Устройство: {device}")

    torch.manual_seed(RANDOM_SEED)
    np.random.seed(RANDOM_SEED)
    random.seed(RANDOM_SEED)

    print("\n1. Загрузка данных")
    print(f"   Train (50% оклюзий): {TRAIN_DIR}")
    print(f"   Val (0% оклюзий): {VAL_DIR}")
    print(f"   Test (70% оклюзий): {TEST_DIR}")

    train_loader, val_loader, test_loader, emotion_labels = create_dataloaders_from_folders(
        train_dir=TRAIN_DIR,
        val_dir=VAL_DIR,
        test_dir=TEST_DIR,
        batch_size=BATCH_SIZE
    )

    print(f"  Train: {len(train_loader.dataset):6d} изображений")
    print(f"  Val:   {len(val_loader.dataset):6d} изображений")
    print(f"  Test:  {len(test_loader.dataset):6d} изображений")

    print(f"\n2. Создание модели (ConvNeXt-Tiny ImageNet)")
    model = ConvNeXtEmotion(num_classes=7, pretrained=True)
    print(f"  Всего параметров: {sum(p.numel() for p in model.parameters()):,}")

    criterion = FocalLoss(gamma=1.5, alpha=None)
    optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=3e-5)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='min',
        factor=0.5,
        patience=3,
        min_lr=1e-7
    )

    print("\n3. Начало обучения")
    history = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        criterion=criterion,
        optimizer=optimizer,
        scheduler=scheduler,
        num_epochs=NUM_EPOCHS,
        device=device,
        patience=12,
        min_delta=0.001,
        checkpoint_dir=CHECKPOINT_DIR
    )

    print("\n4. Визуализация кривых обучения")
    plot_training_history(history)

    print("\n5. Тестирование на выборке с окклюзиями (70% оклюзий)")
    all_preds, all_labels, test_loss, test_acc = test_model(
        model=model,
        test_loader=test_loader,
        criterion=criterion,
        device=device,
        emotion_labels=emotion_labels
    )

    plot_confusion_matrix(all_labels, all_preds, emotion_labels)

    print("\n6. Сохранение")
    os.makedirs("ConvNeXt", exist_ok=True)
    torch.save({
        'model_state_dict': model.state_dict(),
        'history': history,
        'test_acc': test_acc,
    }, f"ConvNeXt/rafdb_convnext_occlusion_trained.pth")
    print(f"Модель сохранена в results/rafdb_convnext_occlusion_trained.pth")

    print("\n")
    print(f"ИТОГОВАЯ ТОЧНОСТЬ НА ТЕСТЕ (70% ОККЛЮЗИЙ): {test_acc:.2f}%")


if __name__ == "__main__":
    main()
# Out:
# РАСПОЗНАВАНИЕ ЭМОЦИЙ НА RAF-DB С ОККЛЮЗИЯМИ
# ConvNeXt-Tiny
# Устройство: cuda
#
# 1. Загрузка данных
#    Train (50% оклюзий): train_occluded_50
#    Val (0% оклюзий): val_original
#    Test (70% оклюзий): occluded_test_dataset
#   Train:  10430 изображений
#   Val:     1841 изображений
#   Test:    3068 изображений
#
# 2. Создание модели (ConvNeXt-Tiny ImageNet)
#   Всего параметров: 28,217,447
#
# 3. Начало обучения
# Чекпоинты будут сохраняться после каждой эпохи в: ./checkpoints_convnext_tiny/
# Early stopping: patience=12, min_delta=0.001
# Epoch 1/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 1/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_001_val72.79.pth   (val acc 72.79%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 72.79% (эпоха 1)
# Epoch  1/50: train 0.8333 / 57.89% | val 0.4832 / 72.79%
# Epoch 2/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 2/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_002_val79.09.pth   (val acc 79.09%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 79.09% (эпоха 2)
# Epoch  2/50: train 0.4870 / 73.85% | val 0.3762 / 79.09%
# Epoch 3/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 3/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_003_val79.41.pth   (val acc 79.41%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 79.41% (эпоха 3)
# Epoch  3/50: train 0.3708 / 79.25% | val 0.3440 / 79.41%
# Epoch 4/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 4/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_004_val81.21.pth   (val acc 81.21%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 81.21% (эпоха 4)
# Epoch  4/50: train 0.2987 / 82.92% | val 0.3259 / 81.21%
# Epoch 5/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 5/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_005_val82.40.pth   (val acc 82.40%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 82.40% (эпоха 5)
# Epoch  5/50: train 0.2408 / 85.36% | val 0.3040 / 82.40%
# Epoch 6/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 6/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_006_val82.94.pth   (val acc 82.94%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 82.94% (эпоха 6)
# Epoch  6/50: train 0.1917 / 88.19% | val 0.3396 / 82.94%
# Epoch 7/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 7/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_007_val82.24.pth   (val acc 82.24%)
# Нет улучшения (1/12)
# Epoch  7/50: train 0.1603 / 89.65% | val 0.3149 / 82.24%
# Epoch 8/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 8/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_008_val82.89.pth   (val acc 82.89%)
# Нет улучшения (2/12)
# Epoch  8/50: train 0.1304 / 91.40% | val 0.3313 / 82.89%
# Epoch 9/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 9/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_009_val83.05.pth   (val acc 83.05%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 83.05% (эпоха 9)
# Epoch  9/50: train 0.1038 / 92.94% | val 0.3541 / 83.05%
# Epoch 10/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 10/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_010_val83.76.pth   (val acc 83.76%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 83.76% (эпоха 10)
# Epoch 10/50: train 0.0691 / 95.34% | val 0.3303 / 83.76%
# Epoch 11/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 11/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_011_val83.49.pth   (val acc 83.49%)
# Нет улучшения (1/12)
# Epoch 11/50: train 0.0557 / 96.05% | val 0.3482 / 83.49%
# Epoch 12/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 12/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_012_val82.94.pth   (val acc 82.94%)
# Нет улучшения (2/12)
# Epoch 12/50: train 0.0457 / 96.61% | val 0.3499 / 82.94%
# Epoch 13/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 13/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_013_val83.11.pth   (val acc 83.11%)
# Нет улучшения (3/12)
# Epoch 13/50: train 0.0466 / 96.64% | val 0.3810 / 83.11%
# Epoch 14/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 14/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_014_val83.54.pth   (val acc 83.54%)
# Нет улучшения (4/12)
# Epoch 14/50: train 0.0370 / 97.42% | val 0.3546 / 83.54%
# Epoch 15/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 15/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_015_val84.03.pth   (val acc 84.03%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 84.03% (эпоха 15)
# Epoch 15/50: train 0.0299 / 97.93% | val 0.3574 / 84.03%
# Epoch 16/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 16/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_016_val84.08.pth   (val acc 84.08%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 84.08% (эпоха 16)
# Epoch 16/50: train 0.0299 / 97.87% | val 0.3755 / 84.08%
# Epoch 17/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 17/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_017_val83.98.pth   (val acc 83.98%)
# Нет улучшения (1/12)
# Epoch 17/50: train 0.0262 / 98.12% | val 0.3627 / 83.98%
# Epoch 18/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 18/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_018_val84.08.pth   (val acc 84.08%)
# Нет улучшения (2/12)
# Epoch 18/50: train 0.0247 / 98.19% | val 0.3822 / 84.08%
# Epoch 19/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 19/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_019_val83.81.pth   (val acc 83.81%)
# Нет улучшения (3/12)
# Epoch 19/50: train 0.0249 / 98.32% | val 0.3711 / 83.81%
# Epoch 20/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 20/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_020_val84.52.pth   (val acc 84.52%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 84.52% (эпоха 20)
# Epoch 20/50: train 0.0214 / 98.47% | val 0.3797 / 84.52%
# Epoch 21/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 21/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_021_val84.30.pth   (val acc 84.30%)
# Нет улучшения (1/12)
# Epoch 21/50: train 0.0193 / 98.69% | val 0.3728 / 84.30%
# Epoch 22/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 22/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_022_val84.03.pth   (val acc 84.03%)
# Нет улучшения (2/12)
# Epoch 22/50: train 0.0199 / 98.60% | val 0.3767 / 84.03%
# Epoch 23/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 23/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_023_val85.01.pth   (val acc 85.01%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 85.01% (эпоха 23)
# Epoch 23/50: train 0.0223 / 98.57% | val 0.3667 / 85.01%
# Epoch 24/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 24/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_024_val84.36.pth   (val acc 84.36%)
# Нет улучшения (1/12)
# Epoch 24/50: train 0.0168 / 98.81% | val 0.3766 / 84.36%
# Epoch 25/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 25/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_025_val84.36.pth   (val acc 84.36%)
# Нет улучшения (2/12)
# Epoch 25/50: train 0.0196 / 98.66% | val 0.3615 / 84.36%
# Epoch 26/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 26/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_026_val85.12.pth   (val acc 85.12%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 85.12% (эпоха 26)
# Epoch 26/50: train 0.0145 / 99.08% | val 0.3663 / 85.12%
# Epoch 27/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 27/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_027_val84.90.pth   (val acc 84.90%)
# Нет улучшения (1/12)
# Epoch 27/50: train 0.0200 / 98.69% | val 0.3695 / 84.90%
# Epoch 28/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 28/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_028_val84.63.pth   (val acc 84.63%)
# Нет улучшения (2/12)
# Epoch 28/50: train 0.0177 / 98.88% | val 0.3653 / 84.63%
# Epoch 29/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 29/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_029_val84.95.pth   (val acc 84.95%)
# Нет улучшения (3/12)
# Epoch 29/50: train 0.0188 / 98.86% | val 0.3706 / 84.95%
# Epoch 30/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 30/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_030_val85.01.pth   (val acc 85.01%)
# Нет улучшения (4/12)
# Epoch 30/50: train 0.0195 / 98.73% | val 0.3678 / 85.01%
# Epoch 31/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 31/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_031_val85.06.pth   (val acc 85.06%)
# Нет улучшения (5/12)
# Epoch 31/50: train 0.0158 / 98.98% | val 0.3667 / 85.06%
# Epoch 32/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 32/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_032_val85.23.pth   (val acc 85.23%)
# НОВАЯ ЛУЧШАЯ МОДЕЛЬ: val acc 85.23% (эпоха 32)
# Epoch 32/50: train 0.0164 / 98.87% | val 0.3650 / 85.23%
# Epoch 33/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 33/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_033_val84.74.pth   (val acc 84.74%)
# Нет улучшения (1/12)
# Epoch 33/50: train 0.0179 / 98.77% | val 0.3717 / 84.74%
# Epoch 34/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 34/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_034_val85.01.pth   (val acc 85.01%)
# Нет улучшения (2/12)
# Epoch 34/50: train 0.0163 / 98.92% | val 0.3699 / 85.01%
# Epoch 35/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 35/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_035_val84.85.pth   (val acc 84.85%)
# Нет улучшения (3/12)
# Epoch 35/50: train 0.0130 / 99.11% | val 0.3669 / 84.85%
# Epoch 36/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 36/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_036_val85.06.pth   (val acc 85.06%)
# Нет улучшения (4/12)
# Epoch 36/50: train 0.0142 / 99.06% | val 0.3655 / 85.06%
# Epoch 37/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 37/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_037_val84.79.pth   (val acc 84.79%)
# Нет улучшения (5/12)
# Epoch 37/50: train 0.0163 / 98.86% | val 0.3681 / 84.79%
# Epoch 38/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 38/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_038_val84.68.pth   (val acc 84.68%)
# Нет улучшения (6/12)
# Epoch 38/50: train 0.0157 / 99.01% | val 0.3670 / 84.68%
# Epoch 39/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 39/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_039_val84.79.pth   (val acc 84.79%)
# Нет улучшения (7/12)
# Epoch 39/50: train 0.0174 / 98.87% | val 0.3685 / 84.79%
# Epoch 40/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 40/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_040_val84.79.pth   (val acc 84.79%)
# Нет улучшения (8/12)
# Epoch 40/50: train 0.0151 / 99.02% | val 0.3692 / 84.79%
# Epoch 41/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 41/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_041_val85.01.pth   (val acc 85.01%)
# Нет улучшения (9/12)
# Epoch 41/50: train 0.0167 / 98.92% | val 0.3663 / 85.01%
# Epoch 42/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 42/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_042_val84.95.pth   (val acc 84.95%)
# Нет улучшения (10/12)
# Epoch 42/50: train 0.0166 / 98.89% | val 0.3669 / 84.95%
# Epoch 43/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 43/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_043_val84.85.pth   (val acc 84.85%)
# Нет улучшения (11/12)
# Epoch 43/50: train 0.0159 / 98.97% | val 0.3666 / 84.85%
# Epoch 44/50 [Train]:   0%|          | 0/326 [00:00<?, ?it/s]
# Epoch 44/50 [Val]  :   0%|          | 0/58 [00:00<?, ?it/s]
# Сохранено: epoch_044_val84.85.pth   (val acc 84.85%)
# Нет улучшения (12/12)
#
# Early stopping на эпохе 44
# Лучшая val acc: 85.23% (эпоха 32)
# Загружена лучшая модель (эп. 32, val acc 85.23%)
#
# 4. Визуализация кривых обучения
# 5. Тестирование на выборке с окклюзиями (70% оклюзий)
# Тестирование:   0%|          | 0/96 [00:00<?, ?it/s]
# Test Loss: 0.3859
# Test Accuracy: 84.84%
# Macro F1-Score: 0.7676
#
# Per-class metrics:
#  Surprise: F1=0.850, Prec=0.855, Rec=0.845
#  Fear: F1=0.604, Prec=0.646, Rec=0.568
#  Disgust: F1=0.571, Prec=0.610, Rec=0.537
#  Happiness: F1=0.937, Prec=0.927, Rec=0.947
#  Sadness: F1=0.816, Prec=0.825, Rec=0.808
#  Anger: F1=0.777, Prec=0.816, Rec=0.741
#  Neutral: F1=0.818, Prec=0.800, Rec=0.837
# 6. Сохранение
# Модель сохранена в results/rafdb_convnext_occlusion_trained.pth
#
#
# ИТОГОВАЯ ТОЧНОСТЬ НА ТЕСТЕ (70% ОККЛЮЗИЙ): 84.84%
